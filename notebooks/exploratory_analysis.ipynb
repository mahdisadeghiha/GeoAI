# %% [markdown]
# # GeoAI Urban Change Detection — Exploratory Analysis
#
# This notebook demonstrates the core change detection pipeline on sample Muscat, Oman rasters.

# %%
import sys
from pathlib import Path

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT / 'backend'))

from app.services.analysis_service import AnalysisService

samples = ROOT / 'data' / 'samples'
t1 = samples / 'sample_t1.tif'
t2 = samples / 'sample_t2.tif'

service = AnalysisService()
result = service.run_analysis(t1, t2, method='baseline')
result.statistics

# %%
import json
print(json.dumps(result.geojson, indent=2)[:2000])
